# %%
import pandas as pd

# %%
constitution = pd.read_csv("constitution.csv")

# %%
constitution
# Out:
#                               country  year  \
# 0                         afghanistan  2004
# 1                             albania  1998
# 2                             algeria  1989
# 3                             andorra  1993
# 4                              angola  2010
# 5                 antigua_and_barbuda  1981
# 6                           argentina  1853
# 7                             armenia  1995
# 8                          azerbaijan  1995
# 9                             bahamas  1973
# 10                            bahrain  2002
# 11                         bangladesh  1972
# 12                           barbados  1966
# 13                            belarus  1994
# 14                             belize  1981
# 15                              benin  1990
# 16                             bhutan  2008
# 17     bolivia_plurinational_state_of  2009
# 18             bosnia_and_herzegovina  1995
# 19                             brazil  1988
# ...

# %%
#Getting to the United States row

# %%
USA = constitution[constitution["country"] == 'united_states_of_america']

# %%
USA['preamble']
# Out:
# 148    We the People of the United States, in Order t...
# Name: preamble, dtype: object

# %%
#Getting to the Colombia row

# %%
COLOM = constitution[constitution["country"] == 'colombia']

# %%
COLOM
# Out:
#      country  year                                           preamble
# 30  colombia  1991  The people of Colombia, In the exercise of the...

# %%
#Getting countries preamble by year of greater than or equal to 1900

# %%
constitution[constitution['year'] >= 1900]
# Out:
#                               country  year  \
# 0                         afghanistan  2004
# 1                             albania  1998
# 2                             algeria  1989
# 3                             andorra  1993
# 4                              angola  2010
# 5                 antigua_and_barbuda  1981
# 7                             armenia  1995
# 8                          azerbaijan  1995
# 9                             bahamas  1973
# 10                            bahrain  2002
# 11                         bangladesh  1972
# 12                           barbados  1966
# 13                            belarus  1994
# 14                             belize  1981
# 15                              benin  1990
# 16                             bhutan  2008
# 17     bolivia_plurinational_state_of  2009
# 18             bosnia_and_herzegovina  1995
# 19                             brazil  1988
# 20                  brunei_darussalam  1959
# ...

# %%
#Getting countries preamble by year of less than or equal to 1900's

# %%
constitution[constitution['year'] <= 1900]
# Out:
#                       country  year  \
# 6                   argentina  1853
# 138                     tonga  1875
# 148  united_states_of_america  1789
#
#                                               preamble
# 6    We, the representatives of the people of the A...
# 138  Granted by His Majesty King George Tupou I on ...
# 148  We the People of the United States, in Order t...

# %%
constitution
# Out:
#                               country  year  \
# 0                         afghanistan  2004
# 1                             albania  1998
# 2                             algeria  1989
# 3                             andorra  1993
# 4                              angola  2010
# 5                 antigua_and_barbuda  1981
# 6                           argentina  1853
# 7                             armenia  1995
# 8                          azerbaijan  1995
# 9                             bahamas  1973
# 10                            bahrain  2002
# 11                         bangladesh  1972
# 12                           barbados  1966
# 13                            belarus  1994
# 14                             belize  1981
# 15                              benin  1990
# 16                             bhutan  2008
# 17     bolivia_plurinational_state_of  2009
# 18             bosnia_and_herzegovina  1995
# 19                             brazil  1988
# ...

# %%
#Searching the preambles of countries based on the string/text 'People'
#NOTE: preambles are cutoff due to being too long

# %%
ppl = constitution[constitution['preamble'].str.contains('People')]
ppl
# Out:
#                                        country  year  \
# 3                                      andorra  1993
# 4                                       angola  2010
# 5                          antigua_and_barbuda  1981
# 7                                      armenia  1995
# 9                                      bahamas  1973
# 11                                  bangladesh  1972
# 13                                     belarus  1994
# 15                                       benin  1990
# 19                                      brazil  1988
# 22                                burkina_faso  1991
# 23                                     burundi  2005
# 25                                    cameroon  1972
# 27                    central_african_republic  2013
# 28                                        chad  1996
# 29                                       china  1982
# 31                                     comoros  2001
# 32            congo_democratic_republic_of_the  2005
# ...

# %%
constitution = pd.read_csv("constitution.csv")
constitution
# Out:
#                               country  year  \
# 0                         afghanistan  2004
# 1                             albania  1998
# 2                             algeria  1989
# 3                             andorra  1993
# 4                              angola  2010
# 5                 antigua_and_barbuda  1981
# 6                           argentina  1853
# 7                             armenia  1995
# 8                          azerbaijan  1995
# 9                             bahamas  1973
# 10                            bahrain  2002
# 11                         bangladesh  1972
# 12                           barbados  1966
# 13                            belarus  1994
# 14                             belize  1981
# 15                              benin  1990
# 16                             bhutan  2008
# 17     bolivia_plurinational_state_of  2009
# 18             bosnia_and_herzegovina  1995
# 19                             brazil  1988
# ...

# %%
#Sort by year oldest to newest
year_sort = constitution.sort_values(by=['year'])  
year_sort
# Out:
#                                    country  year  \
# 148               united_states_of_america  1789
# 6                                argentina  1853
# 138                                  tonga  1875
# 81                           liechtenstein  1921
# 78                                  latvia  1922
# 66                                 ireland  1937
# 63                               indonesia  1945
# 67                                   japan  1946
# 133                                 taiwan  1947
# 73                       korea_republic_of  1948
# 62                                   india  1949
# 51                                 germany  1949
# 34                              costa_rica  1949
# 68                                  jordan  1952
# 47                                  france  1958
# 20                       brunei_darussalam  1959
# 75                                  kuwait  1962
# 116                                  samoa  1962
# ...
